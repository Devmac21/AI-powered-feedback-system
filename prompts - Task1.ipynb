# %%
import pandas as pd
import json
import time
import requests
from google.colab import userdata
from sklearn.metrics import accuracy_score
from tqdm import tqdm

# Load dataset
df = pd.read_csv("/content/yelp.csv")[["text", "stars"]]

# Use a representative subset to avoid rate limits
df = df.sample(60, random_state=42).reset_index(drop=True)

df.head(), df.shape
# Out:
# (                                                text  stars
#  0  We got here around midnight last Friday... the...      4
#  1  Brought a friend from Louisiana here.  She say...      5
#  2  Every friday, my dad and I eat here. We order ...      3
#  3  My husband and I were really, really disappoin...      1
#  4  Love this place!  Was in phoenix 3 weeks for w...      5,
#  (60, 2))

# %%
OPENROUTER_API_KEY = userdata.get("OPENROUTER_API_KEY")
print("API key loaded:", OPENROUTER_API_KEY[:8] + "...")

HEADERS = {
    "Authorization": f"Bearer {OPENROUTER_API_KEY}",
    "Content-Type": "application/json",
}

MODEL = "mistralai/mistral-7b-instruct"
# Out:
# API key loaded: sk-or-v1...

# %%
def call_llm(prompt: str) -> str:
    print("➡️ Calling LLM...")
    payload = {
        "model": MODEL,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.2,
        "max_tokens": 200
    }

    r = requests.post(
        "https://openrouter.ai/api/v1/chat/completions",
        headers=HEADERS,
        data=json.dumps(payload),
        timeout=30
    )

    print("⬅️ Status:", r.status_code)

    if r.status_code != 200:
        print("❌ Error:", r.text)
        r.raise_for_status()

    return r.json()["choices"][0]["message"]["content"].strip()

# %%
print(
    call_llm(
        'Return ONLY valid JSON: {"predicted_stars":5,"explanation":"Great"}'
    )
)
# Out:
# ➡️ Calling LLM...
# ⬅️ Status: 200
# {"predicted_stars":5,"explanation":"Great"}

# %% [markdown]
# Prompts

# %%
def prompt_v1(text):
    return f"""
Classify the Yelp review into a star rating from 1 to 5.
Return ONLY valid JSON:
{{"predicted_stars": <1-5>, "explanation": "<short>"}}

Review:
"{text}"
"""

# %%
def prompt_v2(text):
    return f"""
Use this rubric:
1 = extremely negative
2 = mostly negative
3 = mixed
4 = mostly positive
5 = extremely positive

Return ONLY valid JSON:
{{"predicted_stars": <1-5>, "explanation": "<one sentence>"}}

Review:
"{text}"
"""

# %%
def prompt_v3(text):
    return f"""
Step 1: assess sentiment
Step 2: map to Yelp stars
Step 3: validate consistency

Return ONLY valid JSON:
{{"predicted_stars": <1-5>, "explanation": "<brief>"}}

Review:
"{text}"
"""

# %%
def parse_json(txt):
    try:
        j = json.loads(txt)
        if isinstance(j.get("predicted_stars"), int):
            return j["predicted_stars"], True
    except:
        pass
    return None, False

# %%
def run_experiment(prompt_fn, label):
    print(f"\n===== RUNNING {label} =====")
    preds, valids = [], []

    for i, row in df.iterrows():
        print(f"\nReview {i+1}/{len(df)}")
        out = call_llm(prompt_fn(row["text"]))
        print("Raw:", out)

        pred, ok = parse_json(out)
        preds.append(pred)
        valids.append(ok)

        time.sleep(0.6)  # rate-limit safe

    clean = df.copy()
    clean["pred"] = preds
    clean = clean.dropna()

    acc = accuracy_score(clean["stars"], clean["pred"])
    json_rate = sum(valids) / len(valids)

    print(f"{label} → Accuracy: {acc:.3f}, JSON rate: {json_rate:.2%}")
    return acc, json_rate

# %%
results = []

results.append(("Baseline", *run_experiment(prompt_v1, "Prompt V1")))
results.append(("Rubric", *run_experiment(prompt_v2, "Prompt V2")))
results.append(("Self-Validated", *run_experiment(prompt_v3, "Prompt V3")))
# Out:
# ===== RUNNING Prompt V1 =====
#
# Review 1/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 2/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 3/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 4/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 5/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 6/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 7/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 8/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 9/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The reviewer praises the place for its great ambiance, generous portions, and awesome food, indicating a very positive experience."} [/s]
#
# Review 10/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 11/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 4, "explanation": "The review mentions positive aspects such as good food, ability to handle a large group, and reasonable pricing. However, without specific ratings for food quality, service, cleanliness, etc., it's difficult to definitively assign a 5-star rating. Therefore, a 4-star rating is predicted."}
#
# Review 12/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 13/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> [OUT]
# {"predicted_stars": 5, "explanation": "The review mentions 'Air Jordan,' which is a highly regarded brand, and the exclamation suggests enthusiasm and high satisfaction."}
#  [/OUT]
#
# Review 14/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 15/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 16/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 17/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 18/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 19/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review uses enthusiastic language like 'great' and 'awesome' and highlights a specific favorite item, indicating high satisfaction."} [/s]
#
# Review 20/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 4, "explanation": "The review highlights the convenience and efficiency of the airport, mentioning a quick process from landing to rental car. The reviewer also provides practical advice, indicating a positive experience overall."}
#
# Review 21/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 22/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 23/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 24/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 25/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 26/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 27/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 28/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 29/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 30/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 31/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 32/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 33/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 34/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 35/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 36/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 37/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 38/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 39/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 40/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 1, "explanation": "The review expresses dissatisfaction with the service or product, indicating a negative experience."} [/s]
#
# Review 41/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 42/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 43/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 44/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 45/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 46/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 47/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 48/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 49/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 50/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 51/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 1, "explanation": "The review mentions multiple instances of poor food quality, such as incorrectly labeled dishes, falling apart wontons, greasy lo mein and eggrolls, and a general lack of taste in the lemon chicken. The reviewer also expresses disappointment and dissatisfaction with their multiple attempts to enjoy the restaurant, and compares the food to Panda Express, which is often considered fast food and not high-quality Chinese cuisine."}
#
# Review 52/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 53/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 54/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 55/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 56/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 57/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 58/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 59/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 60/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
# Prompt V1 → Accuracy: 0.667, JSON rate: 5.00%
#
# ===== RUNNING Prompt V2 =====
#
# Review 1/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 2/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 3/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 4, "explanation": "The review highlights positive aspects like good and filling pizza wraps and refreshing iced tea, indicating a mostly positive experience."}
#
# Review 4/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 5/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 5, "explanation": "The reviewer expresses strong enthusiasm and highlights multiple positive aspects of the place, indicating an extremely positive experience."}
#
# Review 6/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 7/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s>
#
# Review 8/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review uses enthusiastic language like 'awesome' and 'awesomer' to express strong positive sentiment."}
#
# Review 9/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 5, "explanation": "The review is extremely positive, highlighting the great food, generous portions, and excellent ambiance."}
#
# Review 10/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 1, "explanation": "The reviewer expresses extreme dissatisfaction with the service and food quality, indicating a very negative experience."}
#
# Review 11/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The reviewer praises the food, service, and affordability, indicating an extremely positive experience."}
#
# Review 12/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 13/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review is extremely positive, expressing high enthusiasm for the Air Jordan brand."}
#
# Review 14/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 15/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 16/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 17/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 18/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 5, "explanation": "The reviewer is highly satisfied with the petite burger option at Red Robin, praising its smaller size and same toppings, making it a great choice for those watching their caloric intake."}
#
# Review 19/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 5, "explanation": "The review uses enthusiastic language like 'great' and 'awesome' to describe the pizza and appetizer."}
#
# Review 20/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 4, "explanation": "The reviewer highlights the convenience and efficiency of the airport, despite its limited commercial options."}
#
# Review 21/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 22/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 23/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 24/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 25/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 26/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 4, "explanation": "The review highlights satisfaction with the food, especially the green chile plate and horchata, and praises the value for money, indicating a mostly positive experience."}
#
# Review 27/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 1, "explanation": "The review expresses strong dissatisfaction with the prices."}
#
# Review 28/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 29/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 3, "explanation": "The review has both positive and negative aspects, such as nice garden department and short check out times, but also complaints about the wood saw and higher prices."}
#
# Review 30/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 31/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 32/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 33/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 4, "explanation": "The reviewer praises the pulled pork and beans, indicating a mostly positive experience despite minor criticisms."}
#
# Review 34/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 35/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 36/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 37/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review expresses extreme satisfaction with the sandwiches, bread, and overall experience."}
#
# Review 38/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 39/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 4, "explanation": "The reviewer praises the food, especially the brisket sandwich, ribs, beans, and homemade root beer, indicating a mostly positive experience despite minor criticisms."}
#
# Review 40/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 1, "explanation": "The review expresses strong dissatisfaction with the product or service, indicating a very negative experience."}
#
# Review 41/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 42/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 43/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 44/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 45/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The reviewer praises the food, service, and atmosphere, indicating an extremely positive experience."}
#
# Review 46/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 5, "explanation": "The review highlights excellent food, friendly staff, and great value, making it extremely positive."}
#
# Review 47/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 48/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The reviewer enthusiastically praises the crab salad and the overall dining experience, indicating a very positive sentiment."}
#
# Review 49/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 4, "explanation": "The reviewer enjoyed the sushi, found the prices fair, and plans to return. However, they also mentioned that some of the rolls were very large and difficult to eat with chopsticks."}
#
# Review 50/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 1, "explanation": "The review expresses extreme dissatisfaction with the taxi service, highlighting poor navigation, wasted time, and financial loss."}
#
# Review 51/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 1, "explanation": "The review expresses extreme dissatisfaction with the food quality and service, indicating a very negative experience."}
#
# Review 52/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 4, "explanation": "The reviewer expresses a clear preference for Waffle House over Denny's, indicating a positive experience."}
#
# Review 53/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The reviewer expresses extreme enthusiasm and positivity about the unique dining experience, the food, and the atmosphere, making it an extremely positive review."}
#
# Review 54/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s>
# {"predicted_stars": 4, "explanation": "The reviewer praises the food, prices, and service, despite noting the shabby appearance, indicating a mostly positive experience."}
#  [/s]
#
# Review 55/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 56/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 3, "explanation": "The review is mixed, praising the layout and view but criticizing the drink prices and lack of well options."}
#
# Review 57/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 58/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 5, "explanation": "The reviewer expresses strong positive emotions and enthusiasm about the product."}
#
# Review 59/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The reviewer expresses extreme satisfaction with the food, service, and overall experience, indicating a highly positive sentiment."}
#
# Review 60/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 2, "explanation": "Price increase and portion size reduction, self-service, and poor tea preparation led to a disappointing experience."}
# Prompt V2 → Accuracy: 0.533, JSON rate: 25.00%
#
# ===== RUNNING Prompt V3 =====
#
# Review 1/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 2/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review mentions the crawfish etouffee being the best outside of Louisiana, which is a very high compliment, indicating excellent quality and likely a 5-star rating."}
#
# Review 3/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 4, "explanation": "Positive words like 'good', 'filling', and 'hits the spot' indicate a favorable experience. The mention of a regular visit suggests satisfaction. The only slight negative is 'typical', but it's not strong enough to lower the rating significantly."}
#
# Review 4/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 5/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review expresses strong positive sentiment with words like 'Love', 'amazing', and 'Must try', indicating a 5-star rating."} [/s]
#
# Review 6/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: ```json
# {
#   "predicted_stars": 4,
#   "explanation": "The review highlights positive aspects such as good location, free parking, clean and spacious rooms, decent breakfast, and a comfortable stay overall. Minor issues like hearing neighbors in the bathroom are noted but do not significantly detract from the overall positive experience. The tone is generally favorable, warranting a 4-star rating."
# }
# ```
#
# Review 7/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review expresses strong positive sentiment with phrases like 'I love', 'Happy hour is good', and 'The best part is'. The reviewer highlights excellent food quality, good service at times, and extended hours, all of which contribute to a 5-star rating."}
#
# Review 8/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review uses strong positive language like 'Awesome' and 'awesomer' with multiple exclamation marks, indicating high enthusiasm. The use of '!!!' suggests the reviewer is very excited about the experience, which aligns with a 5-star rating."} [/s]
#
# Review 9/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s>
# {"predicted_stars": 5, "explanation": "The review uses superlatives like 'great', 'favorite', and 'awesome', and mentions generous portions, indicating a very positive experience."}
#  [/s]
#
# Review 10/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 1, "explanation": "The review explicitly mentions '1 star for service' and expresses dissatisfaction with the food, describing it as 'not ok' and noting a consistent issue with insufficient meat. The negative tone and specific complaints justify a 1-star rating."}
#
# Review 11/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 12/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 13/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review mentions 'Air Jordan,' a highly regarded brand, with an exclamation mark and a rhetorical question, indicating strong positive sentiment."} [/s]
#
# Review 14/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 15/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s>
# {"predicted_stars": 5, "explanation": "The reviewer expresses extreme gratitude and satisfaction with the service, mentioning that the technician was helpful and that they will continue referring the service, which indicates a 5-star rating."}
#
# Review 16/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 3, "explanation": "The review mentions the burger was 'good' but not great, and the fries were 'average'. The prices were criticized as overpriced, particularly for beverages. Overall, the experience was satisfactory but not exceptional, warranting 3 stars."}
#
# Review 17/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 18/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 19/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review uses enthusiastic language like 'great' and 'awesome' with multiple exclamation marks, indicating strong positive sentiment. The mention of a specific favorite appetizer ('guacamole pizza') further supports a high rating."} [/s]
#
# Review 20/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 4, "explanation": "The review is generally positive, highlighting the convenience of the airport and the quick process from landing to rental car. The only minor criticism is about the snacks on the flight, which doesn't significantly detract from the overall positive experience."} [/s]
#
# Review 21/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 22/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 23/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 24/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 25/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 26/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: ```json
# {
#   "predicted_stars": 4,
#   "explanation": "The review highlights positive aspects like perfectly cooked pork, a spicy tomatillo sauce, and a refreshing horchata. The customer was fully satisfied with their meal and found it to be a good value. The only minor downside is that they didn't get burritos, but they still enjoyed their entrees. Overall, the sentiment is strongly positive, warranting 4 stars."
# }
# ```
#
# Review 27/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 1, "explanation": "The review explicitly states that prices are 'way too high,' indicating strong dissatisfaction, which aligns with a 1-star rating."} [/s]
#
# Review 28/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 29/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 3, "explanation": "The review mentions some positive aspects (nice garden department, short check out times) but also several negative points (wood saw out of service, strange staff, higher prices). The overall tone is neutral to slightly negative, warranting a 3-star rating."}
#
# Review 30/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 31/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 32/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 33/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 4, "explanation": "The review mentions positive aspects like the pulled pork (rated 8/10), good sauce, and enjoyable beans, despite minor criticisms about the slaw and location. The overall tone is positive with a clear intention to return, indicating a 4-star rating."}
#
# Review 34/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 35/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 36/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 37/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review uses superlatives like 'best' and 'perfect' to describe the sandwiches and bread, indicating a very positive experience. The reviewer also expresses a strong desire to return, which further suggests high satisfaction."} [/s]
#
# Review 38/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 39/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 4, "explanation": "The review mentions 'delicious' food, 'YUM' for the root beer, and positive comments about the beans and macaroni and cheese. However, there are minor criticisms about the cafeteria style ordering and the coleslaw. Overall, the positive experiences outweigh the negatives, justifying a 4-star rating."} [/s]
#
# Review 40/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 1, "explanation": "The review expresses strong dissatisfaction and mentions wasting money, which are indicative of a low rating."}
#
# Review 41/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 3, "explanation": "The review mentions that the food was mediocre and overpriced, with specific examples of better experiences at other restaurants. The service was good but not exceptional. The creme brulee and coffee were criticized. Based on these points, a rating of 3 stars is predicted."}
#
# Review 42/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 43/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 44/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 45/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review is overwhelmingly positive, highlighting excellent food, great service, and a welcoming atmosphere. The only minor critique is the price, which is expected for a W Hotel. Overall, the sentiment is very positive, warranting a 5-star rating."}
#
# Review 46/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 47/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 48/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 49/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 50/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 51/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: {"predicted_stars": 1, "explanation": "The review mentions multiple instances of poor food quality, such as incorrectly labeled dishes, falling apart wontons, greasy lo mein and eggrolls. The reviewer also expresses disappointment and dissatisfaction with the new owners/staff, and prefers to give their business to locals instead. This suggests a very poor dining experience, resulting in a predicted rating of 1 star."}
#
# Review 52/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 53/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review is overwhelmingly positive, highlighting a unique and enjoyable dining experience with excellent atmosphere and good food. The use of multiple exclamation marks and enthusiastic language supports a 5-star rating."} [/s]
#
# Review 54/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s>
# {"predicted_stars": 4, "explanation": "The review highlights positive aspects like delicious food, decent prices, and friendly staff, despite noting the place is a bit shabby. The overall tone is favorable, justifying a 4-star rating."}
#  [/s]
#
# Review 55/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
#
# Review 56/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s>
# ```json
# {
#   "predicted_stars": 3,
#   "explanation": "The review has both positive and negative aspects. The reviewer loves the layout and view, and supports independent businesses, which suggests a positive sentiment. However, they are turned off by the high drink prices, lack of well options, and uncertainty about the outdoor dance club concept. The mixed feelings lead to a 3-star rating."
# }
# ```
#
# Review 57/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: ```json
# {
#   "predicted_stars": 5,
#   "explanation": "The review highlights multiple positive aspects: excellent food (salmon and bread pudding), great service, fun atmosphere, and flexible hours. The minor issue with the drink was overshadowed by the overall positive experience, leading to a 5-star rating."
# }
# ```
#
# Review 58/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review expresses strong positive sentiment with words like 'in love', 'super delicious', 'inexpensive', and 'yummm', indicating a 5-star rating."}
#
# Review 59/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw: <s> {"predicted_stars": 5, "explanation": "The review expresses strong positive sentiment with phrases like 'never been disappointed,' 'favorite,' and 'excellent service.' The customer also mentions being treated 'friendly and with a smile,' which aligns with a 5-star rating."}
#
# Review 60/60
# ➡️ Calling LLM...
# ⬅️ Status: 200
# Raw:
# Prompt V3 → Accuracy: 0.667, JSON rate: 5.00%

# %%
comparison = pd.DataFrame(
    results,
    columns=["Prompt Strategy", "Accuracy", "JSON Validity Rate"]
)

comparison
# Out:
#   Prompt Strategy  Accuracy  JSON Validity Rate
# 0        Baseline  0.666667                0.05
# 1          Rubric  0.533333                0.25
# 2  Self-Validated  0.666667                0.05
